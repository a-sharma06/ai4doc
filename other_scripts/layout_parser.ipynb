# %% [markdown]
# # Testing Layout Parser
# https://github.com/Layout-Parser/layout-parser/tree/main
# https://github.com/Layout-Parser/layout-parser/blob/main/examples/Deep%20Layout%20Parsing.ipynb

# %%
# %pip install layoutparser==0.3.4
# Out:
# Requirement already satisfied: layoutparser==0.3.4 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (0.3.4)
# Requirement already satisfied: numpy in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (2.0.0)
# Requirement already satisfied: opencv-python in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (1.14.0)
# Requirement already satisfied: pandas in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (2.2.2)
# Requirement already satisfied: pillow in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (10.4.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (6.0.1)
# Requirement already satisfied: iopath in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (0.11.2)
# Requirement already satisfied: pdf2image in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from layoutparser==0.3.4) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from iopath->layoutparser==0.3.4) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from iopath->layoutparser==0.3.4) (4.12.2)
# Requirement already satisfied: portalocker in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from iopath->layoutparser==0.3.4) (2.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pandas->layoutparser==0.3.4) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pandas->layoutparser==0.3.4) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pandas->layoutparser==0.3.4) (2024.1)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pdfplumber->layoutparser==0.3.4) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pdfplumber->layoutparser==0.3.4) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser==0.3.4) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser==0.3.4) (42.0.8)
# Requirement already satisfied: six>=1.5 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from python-dateutil>=2.8.2->pandas->layoutparser==0.3.4) (1.16.0)
# Requirement already satisfied: pywin32>=226 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from portalocker->iopath->layoutparser==0.3.4) (305.1)
# Requirement already satisfied: colorama in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from tqdm->iopath->layoutparser==0.3.4) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser==0.3.4) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\ashar\anaconda3\envs\py312sec\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser==0.3.4) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Obtaining a PDF page as an image

# %%
from glob import glob
import pymupdf  # PyMuPDF

pdfs = glob(r"C:\Users\ashar\repos\ai4doc\pdfs\*.pdf")

# Open the PDF file
doc = pymupdf.open(pdfs[0])

# Select the page
page_number = 0  # page numbers start from 0
page = doc.load_page(page_number)

# Render page to an image
pix = page.get_pixmap()

# Save the image
output_image = "output_image.png"
pix.save(output_image)

print(f"Page {page_number + 1} has been saved as {output_image}")
# Out:
# Page 1 has been saved as output_image.png

# %% [markdown]
# # Parsing the image

# %%
import layoutparser as lp
import cv2

# %%
image = cv2.imread(output_image)
image = image[..., ::-1] 
    # Convert the image from BGR (cv2 default loading style)
    # to RGB

# %%
model = lp.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config', 
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
                                 label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"})
    # Load the deep layout model from the layoutparser API 
    # For all the supported model, please check the Model 
    # Zoo Page: https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model = lp.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
#       2                                  extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
#       3                                  label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"})
#       4     # Load the deep layout model from the layoutparser API
#       5     # For all the supported model, please check the Model
#       6     # Zoo Page: https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html
#
# File c:\Users\ashar\anaconda3\envs\py312sec\Lib\site-packages\layoutparser\file_utils.py:226, in _LazyModule.__getattr__(self, name)
#     224     value = getattr(module, name)
#     225 else:
# --> 226     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#     228 setattr(self, name, value)
#     229 return value
#
# AttributeError: module layoutparser has no attribute Detectron2LayoutModel
